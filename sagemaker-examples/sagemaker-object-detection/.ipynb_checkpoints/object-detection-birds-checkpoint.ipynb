# %% [markdown]
# ## Object detection on the birds dataset.
# ### Details on the dataset
# [Caltech Birds (CUB 200 2011)](https://paperswithcode.com/dataset/cub-200-2011)
#
# RecordIO format is used for training data.
#
# ### Model
# Using Sagemaker's object detection algorithm using Single shot multibox detector (SSD). With a ResNet network.

# %%
# !pip install --upgrade pip
# !pip install boto --upgrade
# !pip install boto3 --upgrade
# !pip install awscli --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (22.3)
# Collecting pip
#   Downloading pip-22.3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 25.6 MB/s eta 0:00:00:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3
#     Uninstalling pip-22.3:
#       Successfully uninstalled pip-22.3
# Successfully installed pip-22.3.1
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting boto
#   Using cached boto-2.49.0-py2.py3-none-any.whl (1.4 MB)
# Installing collected packages: boto
# Successfully installed boto-2.49.0
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (1.26.44)
# Collecting boto3
#   Downloading boto3-1.26.57-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from boto3) (0.6.0)
# Collecting botocore<1.30.0,>=1.29.57
#   Downloading botocore-1.29.57-py3-none-any.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 44.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from botocore<1.30.0,>=1.29.57->boto3) (1.26.8)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from botocore<1.30.0,>=1.29.57->boto3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.57->boto3) (1.16.0)
# Installing collected packages: botocore, boto3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.29.44
#     Uninstalling botocore-1.29.44:
#       Successfully uninstalled botocore-1.29.44
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.26.44
#     Uninstalling boto3-1.26.44:
#       Successfully uninstalled boto3-1.26.44
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# awscli 1.27.44 requires botocore==1.29.44, but you have botocore 1.29.57 which is incompatible.
# Successfully installed boto3-1.26.57 botocore-1.29.57
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: awscli in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (1.27.44)
# Collecting awscli
#   Downloading awscli-1.27.57-py3-none-any.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 43.8 MB/s eta 0:00:00:00:01
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from awscli) (4.7.2)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from awscli) (0.6.0)
# Requirement already satisfied: colorama<0.4.5,>=0.2.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from awscli) (0.4.4)
# Requirement already satisfied: botocore==1.29.57 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from awscli) (1.29.57)
# Requirement already satisfied: PyYAML<5.5,>=3.10 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from awscli) (5.4.1)
# Requirement already satisfied: docutils<0.17,>=0.10 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from awscli) (0.16)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from botocore==1.29.57->awscli) (2.8.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from botocore==1.29.57->awscli) (1.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from botocore==1.29.57->awscli) (1.26.8)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from rsa<4.8,>=3.1.2->awscli) (0.4.8)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.29.57->awscli) (1.16.0)
# Installing collected packages: awscli
#   Attempting uninstall: awscli
#     Found existing installation: awscli 1.27.44
#     Uninstalling awscli-1.27.44:
#       Successfully uninstalled awscli-1.27.44
# Successfully installed awscli-1.27.57

# %%
# These packages are needed to use OpenCV in Studio as of February 2022
import platform
if platform.libc_ver()[0] == "debian":
    ! apt-get update
    ! apt-get install ffmpeg libsm6 libxext6  -y

# %%
import sys

# !{sys.executable} -m pip install opencv-python
# !{sys.executable} -m pip install mxnet
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: opencv-python in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from opencv-python) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting mxnet
#   Downloading mxnet-1.9.1-py3-none-manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 13.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from mxnet) (1.21.6)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests<3,>=2.20.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from mxnet) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3,>=2.20.0->mxnet) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3,>=2.20.0->mxnet) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3,>=2.20.0->mxnet) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests<3,>=2.20.0->mxnet) (2022.9.24)
# Installing collected packages: graphviz, mxnet
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.13.2
#     Uninstalling graphviz-0.13.2:
#       Successfully uninstalled graphviz-0.13.2
# Successfully installed graphviz-0.8.4 mxnet-1.9.1

# %%
import sagemaker

bucket = sagemaker.Session().default_bucket()
prefix = "DEMO-ObjectDetection-birds"

print("s3://{}/{}/".format(bucket, prefix))
# Out:
# s3://sagemaker-eu-west-1-636444261840/DEMO-ObjectDetection-birds/

# %%
from sagemaker import get_execution_role

role = get_execution_role()
print(role)
sess = sagemaker.Session()
# Out:
# arn:aws:iam::636444261840:role/service-role/AmazonSageMaker-ExecutionRole-20221227T094171

# %% [markdown]
# ## Data preparation

# %%
import os
import urllib.request


def download(url):
    filename = url.split("/")[-1]
    if not os.path.exists(filename):
        urllib.request.urlretrieve(url, filename)

# %%
# %%time
# download('http://www.vision.caltech.edu/visipedia-data/CUB-200-2011/CUB_200_2011.tgz')
# CalTech's download is (at least temporarily) unavailable since August 2020.

# Can now use one made available by fast.ai .
download("https://s3.amazonaws.com/fast-ai-imageclas/CUB_200_2011.tgz")
# Out:
# CPU times: user 2.29 s, sys: 2.56 s, total: 4.85 s
# Wall time: 27.7 s

# %%
# %%time
# Clean up prior version of the downloaded dataset if you are running this again
# !rm -rf CUB_200_2011

# Unpack and then remove the downloaded compressed tar file
# !gunzip -c ./CUB_200_2011.tgz | tar xopf -
# !rm CUB_200_2011.tgz
# Out:
# CPU times: user 391 ms, sys: 24.8 ms, total: 416 ms
# Wall time: 26.2 s

# %% [markdown]
# ## Explore the dataset

# %%
import pandas as pd
import cv2
import boto3
import json

runtime = boto3.client(service_name="runtime.sagemaker")

import matplotlib.pyplot as plt

# %matplotlib inline

RANDOM_SPLIT = False
SAMPLE_ONLY = True
FLIP = False

# To speed up training and experimenting, you can use a small handful of species.
# To see the full list of the classes available, look at the content of CLASSES_FILE.
CLASSES = [17, 36, 47, 68, 73]

# Otherwise, you can use the full set of species
if not SAMPLE_ONLY:
    CLASSES = []
    for c in range(200):
        CLASSES += [c + 1]

RESIZE_SIZE = 256

BASE_DIR = "CUB_200_2011/"
IMAGES_DIR = BASE_DIR + "images/"

CLASSES_FILE = BASE_DIR + "classes.txt"
BBOX_FILE = BASE_DIR + "bounding_boxes.txt"
IMAGE_FILE = BASE_DIR + "images.txt"
LABEL_FILE = BASE_DIR + "image_class_labels.txt"
SIZE_FILE = BASE_DIR + "sizes.txt"
SPLIT_FILE = BASE_DIR + "train_test_split.txt"

TRAIN_LST_FILE = "birds_ssd_train.lst"
VAL_LST_FILE = "birds_ssd_val.lst"

if SAMPLE_ONLY:
    TRAIN_LST_FILE = "birds_ssd_sample_train.lst"
    VAL_LST_FILE = "birds_ssd_sample_val.lst"

TRAIN_RATIO = 0.8
CLASS_COLS = ["class_number", "class_id"]
IM2REC_SSD_COLS = [
    "header_cols",
    "label_width",
    "zero_based_id",
    "xmin",
    "ymin",
    "xmax",
    "ymax",
    "image_file_name",
]
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
def show_species(species_id):
    """
    Shows all images in dataset for a given species_id
    args: species_id
    """
    # internal list in scope of function
    _im_list = !ls $IMAGES_DIR/$species_id

    NUM_COLS = 6
    IM_COUNT = len(_im_list)

    print('Species ' + species_id + ' has ' + str(IM_COUNT) + ' images.')

    NUM_ROWS = int(IM_COUNT / NUM_COLS)
    if ((IM_COUNT % NUM_COLS) > 0):
        NUM_ROWS += 1

    fig, axarr = plt.subplots(NUM_ROWS, NUM_COLS)
    fig.set_size_inches(8.0, 16.0, forward=True)

    curr_row = 0
    for curr_img in range(IM_COUNT):
        # fetch the url as a file type object, then read the image
        f = IMAGES_DIR + species_id + '/' + _im_list[curr_img]
        a = plt.imread(f)

        # find the column by taking the current index modulo number of rows
        # is plotting rowwise.
        col = curr_img % NUM_ROWS
        # plot on relevant subplot
        axarr[col, curr_row].imshow(a)
        if col == (NUM_ROWS - 1):
            # we have finished the current row, so increment row counter
            curr_row += 1

    fig.tight_layout()
    plt.show()

    # Clean up
    plt.clf() # clean figure
    plt.cla() # clean axes
    plt.close()

# %%
show_species('001.Black_footed_Albatross')
# Out:
# Species 001.Black_footed_Albatross has 60 images.

# %% [markdown]
# ### (Aside) Recommended way to now plot an image
#
# ```python
# from PIL import Image
#
# example_img = IMAGES_DIR + '001.Black_footed_Albatross/' + _im_list[0]
#
# with Image.open(example_img) as im:
#     im.show()
# ```

# %%
classes_df = pd.read_csv(CLASSES_FILE, sep=" ", names=CLASS_COLS, header=None)
criteria = classes_df["class_number"].isin(CLASSES)
classes_df = classes_df[criteria]
print(classes_df.to_csv(columns=["class_id"], sep="\t", index=False, header=False))
# Out:
# 017.Cardinal
# 036.Northern_Flicker
# 047.American_Goldfinch
# 068.Ruby_throated_Hummingbird
# 073.Blue_Jay

# %% [markdown]
# ## Generate RecordIO Files
# The bounding box annotations in `CUB_200_2011/bounding_boxes.txt` are in absolute terms. They will also have to be resized along with the images using the same scaling factor because RecordIO formats require bboxes in relative terms. Here we calculate the size of the images.

# %%
from ipywidgets import IntProgress

# %%
# %%time
SIZE_COLS = ["idx", "width", "height"]


def gen_image_size_file():
    print("Generating a file containing image sizes...")
    images_df = pd.read_csv(
        IMAGE_FILE, sep=" ", names=["image_pretty_name", "image_file_name"], header=None
    )
    rows_list = []
    idx = 0
    f = IntProgress(idx=0, max=images_df.shape[0]) # instantiate the bar
    display(f) # display the bar
    for i in images_df["image_file_name"]:
        f.value += 1
        idx += 1
        img = cv2.imread(IMAGES_DIR + i)
        dimensions = img.shape
        height = img.shape[0]
        width = img.shape[1]
        image_dict = {"idx": idx, "width": width, "height": height}
        rows_list.append(image_dict)

    sizes_df = pd.DataFrame(rows_list)
    print("Image sizes:\n" + str(sizes_df.head(5)))

    sizes_df[SIZE_COLS].to_csv(SIZE_FILE, sep=" ", index=False, header=None)
    


gen_image_size_file()
# Out:
# Generating a file containing image sizes...
# IntProgress(value=0, max=11788)
# Image sizes:
#    idx  width  height
# 0    1    500     335
# 1    2    500     336
# 2    3    500     347
# 3    4    415     500
# 4    5    331     380
# CPU times: user 1min 8s, sys: 2.45 s, total: 1min 10s
# Wall time: 1min 9s

# %%
def split_to_train_test(df, label_column, train_frac=0.8):
    train_df, test_df = pd.DataFrame(), pd.DataFrame()
    labels = df[label_column].unique()
    for lbl in labels:
        lbl_df = df[df[label_column] == lbl]
        lbl_train_df = lbl_df.sample(frac=train_frac)
        lbl_test_df = lbl_df.drop(lbl_train_df.index)
        print(
            "\n{}:\n---------\ntotal:{}\ntrain_df:{}\ntest_df:{}".format(
                lbl, len(lbl_df), len(lbl_train_df), len(lbl_test_df)
            )
        )
        train_df = train_df.append(lbl_train_df)
        test_df = test_df.append(lbl_test_df)
    return train_df, test_df


def gen_list_files():
    # use generated sizes file
    sizes_df = pd.read_csv(
        SIZE_FILE, sep=" ", names=["image_pretty_name", "width", "height"], header=None
    )
    bboxes_df = pd.read_csv(
        BBOX_FILE,
        sep=" ",
        names=["image_pretty_name", "x_abs", "y_abs", "bbox_width", "bbox_height"],
        header=None,
    )
    split_df = pd.read_csv(
        SPLIT_FILE, sep=" ", names=["image_pretty_name", "is_training_image"], header=None
    )
    print(IMAGE_FILE)
    images_df = pd.read_csv(
        IMAGE_FILE, sep=" ", names=["image_pretty_name", "image_file_name"], header=None
    )
    print("num images total: " + str(images_df.shape[0]))
    image_class_labels_df = pd.read_csv(
        LABEL_FILE, sep=" ", names=["image_pretty_name", "class_id"], header=None
    )

    # Merge the metadata into a single flat dataframe for easier processing
    full_df = pd.DataFrame(images_df)
    full_df.reset_index(inplace=True)
    full_df = pd.merge(full_df, image_class_labels_df, on="image_pretty_name")
    full_df = pd.merge(full_df, sizes_df, on="image_pretty_name")
    full_df = pd.merge(full_df, bboxes_df, on="image_pretty_name")
    full_df = pd.merge(full_df, split_df, on="image_pretty_name")
    full_df.sort_values(by=["index"], inplace=True)

    # Define the bounding boxes in the format required by SageMaker's built in Object Detection algorithm.
    # the xmin/ymin/xmax/ymax parameters are specified as ratios to the total image pixel size
    full_df["header_cols"] = 2  # one col for the number of header cols, one for the label width
    full_df["label_width"] = 5  # number of cols for each label: class, xmin, ymin, xmax, ymax
    full_df["xmin"] = full_df["x_abs"] / full_df["width"]
    full_df["xmax"] = (full_df["x_abs"] + full_df["bbox_width"]) / full_df["width"]
    full_df["ymin"] = full_df["y_abs"] / full_df["height"]
    full_df["ymax"] = (full_df["y_abs"] + full_df["bbox_height"]) / full_df["height"]

    # object detection class id's must be zero based. map from
    # class_id's given by CUB to zero-based (1 is 0, and 200 is 199).

    if SAMPLE_ONLY:
        # grab a small subset of species for testing
        criteria = full_df["class_id"].isin(CLASSES)
        full_df = full_df[criteria]

    unique_classes = full_df["class_id"].drop_duplicates()
    sorted_unique_classes = sorted(unique_classes)

    id_to_zero = {}
    i = 0.0
    for c in sorted_unique_classes:
        id_to_zero[c] = i
        i += 1.0

    full_df["zero_based_id"] = full_df["class_id"].map(id_to_zero)

    full_df.reset_index(inplace=True)

    # use 4 decimal places, as it seems to be required by the Object Detection algorithm
    pd.set_option("display.precision", 4)

    train_df = []
    val_df = []

    if RANDOM_SPLIT:
        # split into training and validation sets
        train_df, val_df = split_to_train_test(full_df, "class_id", TRAIN_RATIO)

        train_df[IM2REC_SSD_COLS].to_csv(TRAIN_LST_FILE, sep="\t", float_format="%.4f", header=None)
        val_df[IM2REC_SSD_COLS].to_csv(VAL_LST_FILE, sep="\t", float_format="%.4f", header=None)
    else:
        train_df = full_df[(full_df.is_training_image == 1)]
        train_df[IM2REC_SSD_COLS].to_csv(TRAIN_LST_FILE, sep="\t", float_format="%.4f", header=None)

        val_df = full_df[(full_df.is_training_image == 0)]
        val_df[IM2REC_SSD_COLS].to_csv(VAL_LST_FILE, sep="\t", float_format="%.4f", header=None)

    print("num train: " + str(train_df.shape[0]))
    print("num val: " + str(val_df.shape[0]))
    return train_df, val_df

# %%
train_df, val_df = gen_list_files()
# Out:
# CUB_200_2011/images.txt
# num images total: 11788
# num train: 150
# num val: 147

# %% [markdown]
# # Looking at this dataset
# The dataset generated the training data: `TRAIN_LST_FILE`.
# Can view the tail with `!tail -3 $TRAIN_LST_FILE`
# - index = image number
# - class_id = label
# - label_width (indicates each image has 5 numbers to describe the label information: the class label and the 4 relative coordinates of the bounding box). If there were multiple objects per image, we'd still list it all on one line.
# - zero_based_id = class label (zero-indexed)
# - Bounding box coordinates = Bounding box coordinates are ratios of its top-left (xmin, ymin) and bottom-right (xmax, ymax) corner indices to the overall image size. Top

# %%
train_df.head(5)
# Out:
#     level_0  index  image_pretty_name                       image_file_name  \
# 2       897    897                898  017.Cardinal/Cardinal_0085_19162.jpg
# 4       899    899                900  017.Cardinal/Cardinal_0094_17165.jpg
# 6       901    901                902  017.Cardinal/Cardinal_0045_18021.jpg
# 10      905    905                906  017.Cardinal/Cardinal_0054_19334.jpg
# 11      906    906                907  017.Cardinal/Cardinal_0075_17946.jpg
#
#     class_id  width  height  x_abs  y_abs  bbox_width  bbox_height  \
# 2         17    500     334  118.0   19.0       354.0        291.0
# 4         17    500     348  113.0   36.0       311.0        185.0
# 6         17    400     500  167.0   73.0       194.0        404.0
# 10        17    435     500   65.0   77.0       316.0        365.0
# 11        17    399     500   91.0  118.0       185.0        276.0
#
#     is_training_image  header_cols  label_width    xmin    xmax    ymin  \
# 2                   1            2            5  0.2360  0.9440  0.0569
# 4                   1            2            5  0.2260  0.8480  0.1034
# 6                   1            2            5  0.4175  0.9025  0.1460
# 10                  1            2            5  0.1494  0.8759  0.1540
# 11                  1            2            5  0.2281  0.6917  0.2360
#
#       ymax  zero_based_id
# 2   0.9281            0.0
# 4   0.6351            0.0
# 6   0.9540            0.0
# 10  0.8840            0.0
# 11  0.7880            0.0

# %%
# !tail -3 $TRAIN_LST_FILE
# Out:
# 291	2	5	4.0000	0.4080	0.1527	0.9880	0.8728	073.Blue_Jay/Blue_Jay_0048_62433.jpg
# 294	2	5	4.0000	0.2500	0.1455	0.8260	0.8303	073.Blue_Jay/Blue_Jay_0086_63394.jpg
# 296	2	5	4.0000	0.2960	0.5400	0.8160	0.8460	073.Blue_Jay/Blue_Jay_0074_63487.jpg

# %% [markdown]
# ## Convert data into RecordIO format

# %%
# generates .idx and .rec files
# !python tools/im2rec.py --resize $RESIZE_SIZE --pack-label birds_ssd_sample $BASE_DIR/images/
# Out:
# Creating .rec file from /home/ec2-user/SageMaker/supple-pose/sagemaker-examples/sagemaker-object-detection/birds_ssd_sample_train.lst in /home/ec2-user/SageMaker/supple-pose/sagemaker-examples/sagemaker-object-detection
# multiprocessing not available, fall back to single threaded encoding
# time: 0.23058319091796875  count: 0
# Creating .rec file from /home/ec2-user/SageMaker/supple-pose/sagemaker-examples/sagemaker-object-detection/birds_ssd_sample_val.lst in /home/ec2-user/SageMaker/supple-pose/sagemaker-examples/sagemaker-object-detection
# multiprocessing not available, fall back to single threaded encoding
# time: 0.00551295280456543  count: 0

# %% [markdown]
# ## Upload RecordIO files to S3
# The .rec file extensions

# %%
# Upload the RecordIO files to train and validation channels
train_channel = prefix + "/train"
validation_channel = prefix + "/validation"

sess.upload_data(path="birds_ssd_sample_train.rec", bucket=bucket, key_prefix=train_channel)
sess.upload_data(path="birds_ssd_sample_val.rec", bucket=bucket, key_prefix=validation_channel)

s3_train_data = "s3://{}/{}".format(bucket, train_channel)
s3_validation_data = "s3://{}/{}".format(bucket, validation_channel)

# %% [markdown]
# # Train the model
# Save model artifacts (after training) in S3.
# Also get the URI (uniform resource identifier) of the object detection docker image. The docker image URI is from AWS ECR (elastic container registry).

# %%
from sagemaker import image_uris

training_image = image_uris.retrieve(
    region=sess.boto_region_name, framework="object-detection", version="latest"
)
print(training_image)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: latest.
# 685385470294.dkr.ecr.eu-west-1.amazonaws.com/object-detection:1

# %%
s3_output_location = "s3://{}/{}/output".format(bucket, prefix)

# %%
## object detection model
## note large volume size for image
od_model = sagemaker.estimator.Estimator(
    training_image,
    role,
    instance_count=1,
    instance_type="ml.p3.2xlarge",
    volume_size=50,
    max_run=360000,
    input_mode="File",
    output_path=s3_output_location,
    sagemaker_session=sess,
)

# %% [markdown]
# [Object detection documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/object-detection.html) for training hyperparameters.

# %%
def set_hyperparameters(num_epochs, lr_steps):
    num_classes = classes_df.shape[0]
    num_training_samples = train_df.shape[0]
    print("num classes: {}, num training images: {}".format(num_classes, num_training_samples))

    od_model.set_hyperparameters(
        base_network="resnet-50",
        use_pretrained_model=1,
        num_classes=num_classes,
        mini_batch_size=16,
        epochs=num_epochs,
        learning_rate=0.001,
        lr_scheduler_step=lr_steps,
        lr_scheduler_factor=0.1,
        optimizer="sgd",
        momentum=0.9,
        weight_decay=0.0005,
        overlap_threshold=0.5,
        nms_threshold=0.45,
        image_shape=512,
        label_width=350,
        num_training_samples=num_training_samples,
    )

# %%
# question: what is lr_schedule_step?
# surprised that the base network is a hyperparam.

set_hyperparameters(100, "33,67")
# Out:
# num classes: 5, num training images: 150

# %% [markdown]
# ### Create data channel dicts

# %%
train_data = sagemaker.inputs.TrainingInput(
    s3_train_data,
    distribution="FullyReplicated",
    content_type="application/x-recordio",
    s3_data_type="S3Prefix",
)
validation_data = sagemaker.inputs.TrainingInput(
    s3_validation_data,
    distribution="FullyReplicated",
    content_type="application/x-recordio",
    s3_data_type="S3Prefix",
)
data_channels = {"train": train_data, "validation": validation_data}

# %% [markdown]
# ## Submit the training job
# Fit the model.
#
# Steps in the training process:
# 1. Prepare the instances (where Estimator is created and libraries are installed).
# 2. Download the training data
# 3. Training begins (can be tracked in Cloudwatch). There might be some provisioning of resources. It is viewable in the Sagemaker->Training jobs page.
# 4. Can view the metric we are tuning for: mAP in Cloudwatch. Log groups are in `/aws/sagemaker/TrainingJobs/<>` These will be printed on every epoch. Seen in the logs as `#qualitymetric` and there is also a `#progressmetric`.
# 5. Job finished and the model artifacts will be in the S3 bucket.

# %%
# %%time
od_model.fit(inputs=data_channels, logs=True)
# Out:
# INFO:sagemaker:Creating training-job with name: object-detection-2023-01-25-21-52-12-125
# 2023-01-25 21:52:12 Starting - Starting the training job...
# 2023-01-25 21:52:35 Starting - Preparing the instances for training......
# 2023-01-25 21:53:42 Downloading - Downloading input data...
# 2023-01-25 21:54:03 Training - Downloading the training image...............
# 2023-01-25 21:56:29 Training - Training image download completed. Training in progress....Docker entrypoint called with argument(s): train
# Running default environment configuration script
# Nvidia gpu devices, drivers and cuda toolkit versions (only available on hosts with GPU):
# Wed Jan 25 21:57:00 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.65.07    Driver Version: 515.65.07    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:00:1E.0 Off |                    0 |
# | N/A   43C    P0    25W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Checking for nvidia driver and cuda compatibility.
# CUDA Compatibility driver provided.
# Proceeding with compatibility check between driver, cuda-toolkit and cuda-compat.
# Detected cuda-toolkit version: 11.1.
# Detected cuda-compat version: 455.32.00.
# Detected Nvidia driver version: 515.65.07.
# Nvidia driver compatible with cuda-toolkit. Disabling cuda-compat.
# Running custom environment configuration script
# [01/25/2023 21:57:03 INFO 139680548325184] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/default-input.json: {'base_network': 'vgg-16', 'use_pretrained_model': '0', 'num_classes': '', 'mini_batch_size': '32', 'epochs': '30', 'learning_rate': '0.001', 'lr_scheduler_step': '', 'lr_scheduler_factor': '0.1', 'optimizer': 'sgd', 'momentum': '0.9', 'weight_decay': '0.0005', 'overlap_threshold': '0.5', 'nms_threshold': '0.45', 'num_training_samples': '', 'image_shape': '300', '_tuning_objective_metric': '', '_kvstore': 'device', 'kv_store': 'device', '_num_kv_servers': 'auto', 'label_width': '350', 'freeze_layer_pattern': '', 'nms_topk': '400', 'early_stopping': 'False', 'early_stopping_min_epochs': '10', 'early_stopping_patience': '5', 'early_stopping_tolerance': '0.0', '_begin_epoch': '0'}
# [01/25/2023 21:57:03 INFO 139680548325184] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'base_network': 'resnet-50', 'epochs': '100', 'image_shape': '512', 'label_width': '350', 'learning_rate': '0.001', 'lr_scheduler_factor': '0.1', 'lr_scheduler_step': '33,67', 'mini_batch_size': '16', 'momentum': '0.9', 'nms_threshold': '0.45', 'num_classes': '5', 'num_training_samples': '150', 'optimizer': 'sgd', 'overlap_threshold': '0.5', 'use_pretrained_model': '1', 'weight_decay': '0.0005'}
# [01/25/2023 21:57:03 INFO 139680548325184] Final configuration: {'base_network': 'resnet-50', 'use_pretrained_model': '1', 'num_classes': '5', 'mini_batch_size': '16', 'epochs': '100', 'learning_rate': '0.001', 'lr_scheduler_step': '33,67', 'lr_scheduler_factor': '0.1', 'optimizer': 'sgd', 'momentum': '0.9', 'weight_decay': '0.0005', 'overlap_threshold': '0.5', 'nms_threshold': '0.45', 'num_training_samples': '150', 'image_shape': '512', '_tuning_objective_metric': '', '_kvstore': 'device', 'kv_store': 'device', '_num_kv_servers': 'auto', 'label_width': '350', 'freeze_layer_pattern': '', 'nms_topk': '400', 'early_stopping': 'False', 'early_stopping_min_epochs': '10', 'early_stopping_patience': '5', 'early_stopping_tolerance': '0.0', '_begin_epoch': '0'}
# Process 7 is a worker.
# [01/25/2023 21:57:03 INFO 139680548325184] Using default worker.
# [01/25/2023 21:57:03 INFO 139680548325184] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [01/25/2023 21:57:03 INFO 139680548325184] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [01/25/2023 21:57:03 INFO 139680548325184] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [01/25/2023 21:57:03 INFO 139680548325184] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [01/25/2023 21:57:03 INFO 139680548325184] Checkpoint loading and saving are disabled.
# [01/25/2023 21:57:04 INFO 139680548325184] nvidia-smi: took 0.031 seconds to run.
# [01/25/2023 21:57:04 INFO 139680548325184] nvidia-smi identified 1 GPUs.
# [01/25/2023 21:57:04 INFO 139680548325184] Number of GPUs being used: 1
# [01/25/2023 21:57:04 WARNING 139680548325184] Training images are resized to image shape (3, 512, 512)
# [21:57:04] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.38.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/train/birds_ssd_sample_train.rec, use 7 threads for decoding..
# [21:57:04] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.38.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/train/birds_ssd_sample_train.rec, label padding width: 350
# [01/25/2023 21:57:04 WARNING 139680548325184] Validation images are resized to image shape (3, 512, 512)
# [21:57:04] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.38.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/validation/birds_ssd_sample_val.rec, use 7 threads for decoding..
# [21:57:04] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.38.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/validation/birds_ssd_sample_val.rec, label padding width: 350
# [01/25/2023 21:57:05 INFO 139680548325184] Number of GPUs being used: 1
# [01/25/2023 21:57:05 INFO 139680548325184] Using [gpu(0)] as training context.
# [01/25/2023 21:57:05 INFO 139680548325184] Number of GPUs being used: 1
# [01/25/2023 21:57:05 INFO 139680548325184] Create Store: device
# [01/25/2023 21:57:05 INFO 139680548325184] Using (gpu(0)) as training context.
# [01/25/2023 21:57:05 INFO 139680548325184] Start training from pretrained model 1.
# [21:57:05] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.38.0/AL2_x86_64/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [21:57:05] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.38.0/AL2_x86_64/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [01/25/2023 21:57:05 INFO 139680548325184] Loaded pretrained model parameters.
# [01/25/2023 21:57:09 INFO 139680548325184] Creating a new state instance.
# #metrics {"StartTime": 1674683829.6229181, "EndTime": 1674683829.6229827, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [21:57:09] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.38.0/AL2_x86_64/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [01/25/2023 21:57:17 INFO 139680548325184] #quality_metric: host=algo-1, epoch=0, batch=10 train cross_entropy <loss>=(2.1383707168999067)
# [01/25/2023 21:57:17 INFO 139680548325184] #quality_metric: host=algo-1, epoch=0, batch=10 train smooth_l1 <loss>=(0.6886570641753871)
# [01/25/2023 21:57:17 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:57:18 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:57:19 INFO 139680548325184] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(2.6688788927053795e-05)
# [01/25/2023 21:57:19 INFO 139680548325184] Updating the best model with validation-mAP=2.6688788927053795e-05
# [01/25/2023 21:57:19 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:57:19 INFO 139680548325184] #progress_metric: host=algo-1, completed 1.0 % of epochs
# #metrics {"StartTime": 1674683829.6232874, "EndTime": 1674683839.9696035, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:57:22 INFO 139680548325184] #quality_metric: host=algo-1, epoch=1, batch=9 train cross_entropy <loss>=(1.8650421839037377)
# [01/25/2023 21:57:22 INFO 139680548325184] #quality_metric: host=algo-1, epoch=1, batch=9 train smooth_l1 <loss>=(0.6656073653351716)
# [01/25/2023 21:57:22 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:57:22 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:57:24 INFO 139680548325184] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(6.289320456285138e-05)
# [01/25/2023 21:57:24 INFO 139680548325184] Updating the best model with validation-mAP=6.289320456285138e-05
# [01/25/2023 21:57:24 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:57:24 INFO 139680548325184] #progress_metric: host=algo-1, completed 2.0 % of epochs
# #metrics {"StartTime": 1674683839.969817, "EndTime": 1674683844.9037795, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:57:27 INFO 139680548325184] #quality_metric: host=algo-1, epoch=2, batch=10 train cross_entropy <loss>=(1.8301575813151647)
# [01/25/2023 21:57:27 INFO 139680548325184] #quality_metric: host=algo-1, epoch=2, batch=10 train smooth_l1 <loss>=(0.6529053400883444)
# [01/25/2023 21:57:27 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:57:28 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:57:29 INFO 139680548325184] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(0.00024239371326837967)
# [01/25/2023 21:57:29 INFO 139680548325184] Updating the best model with validation-mAP=0.00024239371326837967
# [01/25/2023 21:57:30 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:57:30 INFO 139680548325184] #progress_metric: host=algo-1, completed 3.0 % of epochs
# #metrics {"StartTime": 1674683844.904006, "EndTime": 1674683850.1020446, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:57:32 INFO 139680548325184] #quality_metric: host=algo-1, epoch=3, batch=9 train cross_entropy <loss>=(1.81755829628847)
# [01/25/2023 21:57:32 INFO 139680548325184] #quality_metric: host=algo-1, epoch=3, batch=9 train smooth_l1 <loss>=(0.6386896756348643)
# [01/25/2023 21:57:32 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:57:32 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:57:34 INFO 139680548325184] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.0003971973588616346)
# [01/25/2023 21:57:34 INFO 139680548325184] Updating the best model with validation-mAP=0.0003971973588616346
# [01/25/2023 21:57:34 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:57:34 INFO 139680548325184] #progress_metric: host=algo-1, completed 4.0 % of epochs
# #metrics {"StartTime": 1674683850.1022825, "EndTime": 1674683854.963114, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:57:37 INFO 139680548325184] #quality_metric: host=algo-1, epoch=4, batch=9 train cross_entropy <loss>=(1.8002181419959435)
# [01/25/2023 21:57:37 INFO 139680548325184] #quality_metric: host=algo-1, epoch=4, batch=9 train smooth_l1 <loss>=(0.6442746343882942)
# [01/25/2023 21:57:37 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:57:37 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:57:39 INFO 139680548325184] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(0.0006253163766001822)
# [01/25/2023 21:57:39 INFO 139680548325184] Updating the best model with validation-mAP=0.0006253163766001822
# [01/25/2023 21:57:39 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:57:39 INFO 139680548325184] #progress_metric: host=algo-1, completed 5.0 % of epochs
# #metrics {"StartTime": 1674683854.9633312, "EndTime": 1674683859.8834832, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:57:42 INFO 139680548325184] #quality_metric: host=algo-1, epoch=5, batch=10 train cross_entropy <loss>=(1.7823947880989957)
# [01/25/2023 21:57:42 INFO 139680548325184] #quality_metric: host=algo-1, epoch=5, batch=10 train smooth_l1 <loss>=(0.631766624414249)
# [01/25/2023 21:57:42 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:57:42 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:57:44 INFO 139680548325184] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.0008628588447176037)
# [01/25/2023 21:57:44 INFO 139680548325184] Updating the best model with validation-mAP=0.0008628588447176037
# [01/25/2023 21:57:45 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:57:45 INFO 139680548325184] #progress_metric: host=algo-1, completed 6.0 % of epochs
# #metrics {"StartTime": 1674683859.8836954, "EndTime": 1674683865.030063, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 5, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:57:47 INFO 139680548325184] #quality_metric: host=algo-1, epoch=6, batch=9 train cross_entropy <loss>=(1.768496307437025)
# [01/25/2023 21:57:47 INFO 139680548325184] #quality_metric: host=algo-1, epoch=6, batch=9 train smooth_l1 <loss>=(0.6212543511540635)
# [01/25/2023 21:57:47 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:57:47 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:57:49 INFO 139680548325184] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(0.0011424908876850562)
# [01/25/2023 21:57:49 INFO 139680548325184] Updating the best model with validation-mAP=0.0011424908876850562
# [01/25/2023 21:57:49 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:57:49 INFO 139680548325184] #progress_metric: host=algo-1, completed 7.0 % of epochs
# #metrics {"StartTime": 1674683865.0302603, "EndTime": 1674683869.8677828, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 6, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:57:52 INFO 139680548325184] #quality_metric: host=algo-1, epoch=7, batch=9 train cross_entropy <loss>=(1.7522891077779241)
# [01/25/2023 21:57:52 INFO 139680548325184] #quality_metric: host=algo-1, epoch=7, batch=9 train smooth_l1 <loss>=(0.6273164940081356)
# [01/25/2023 21:57:52 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:57:52 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:57:54 INFO 139680548325184] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.0028529573277200158)
# [01/25/2023 21:57:54 INFO 139680548325184] Updating the best model with validation-mAP=0.0028529573277200158
# [01/25/2023 21:57:54 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:57:54 INFO 139680548325184] #progress_metric: host=algo-1, completed 8.0 % of epochs
# #metrics {"StartTime": 1674683869.8679767, "EndTime": 1674683874.5687213, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 7, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:57:57 INFO 139680548325184] #quality_metric: host=algo-1, epoch=8, batch=10 train cross_entropy <loss>=(1.74268294980862)
# [01/25/2023 21:57:57 INFO 139680548325184] #quality_metric: host=algo-1, epoch=8, batch=10 train smooth_l1 <loss>=(0.621892748034469)
# [01/25/2023 21:57:57 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:57:57 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:57:59 INFO 139680548325184] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(0.004772071826881158)
# [01/25/2023 21:57:59 INFO 139680548325184] Updating the best model with validation-mAP=0.004772071826881158
# [01/25/2023 21:57:59 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:57:59 INFO 139680548325184] #progress_metric: host=algo-1, completed 9.0 % of epochs
# #metrics {"StartTime": 1674683874.568904, "EndTime": 1674683879.9669876, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 8, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 9.0, "count": 1, "min": 9, "max": 9}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:58:02 INFO 139680548325184] #quality_metric: host=algo-1, epoch=9, batch=9 train cross_entropy <loss>=(1.7339895064976247)
# [01/25/2023 21:58:02 INFO 139680548325184] #quality_metric: host=algo-1, epoch=9, batch=9 train smooth_l1 <loss>=(0.6415719404092373)
# [01/25/2023 21:58:02 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:58:02 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:58:04 INFO 139680548325184] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(0.0055451349818129506)
# [01/25/2023 21:58:04 INFO 139680548325184] Updating the best model with validation-mAP=0.0055451349818129506
# [01/25/2023 21:58:05 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:58:05 INFO 139680548325184] #progress_metric: host=algo-1, completed 10.0 % of epochs
# #metrics {"StartTime": 1674683879.9672184, "EndTime": 1674683885.116897, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 9, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:58:08 INFO 139680548325184] #quality_metric: host=algo-1, epoch=10, batch=10 train cross_entropy <loss>=(1.7163019918097466)
# [01/25/2023 21:58:08 INFO 139680548325184] #quality_metric: host=algo-1, epoch=10, batch=10 train smooth_l1 <loss>=(0.6307883166993586)
# [01/25/2023 21:58:08 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:58:08 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:58:09 INFO 139680548325184] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(0.00583041198730053)
# [01/25/2023 21:58:09 INFO 139680548325184] Updating the best model with validation-mAP=0.00583041198730053
# [01/25/2023 21:58:10 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:58:10 INFO 139680548325184] #progress_metric: host=algo-1, completed 11.0 % of epochs
# #metrics {"StartTime": 1674683885.1171324, "EndTime": 1674683890.1929634, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 10, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:58:12 INFO 139680548325184] #quality_metric: host=algo-1, epoch=11, batch=9 train cross_entropy <loss>=(1.7000825614259953)
# [01/25/2023 21:58:12 INFO 139680548325184] #quality_metric: host=algo-1, epoch=11, batch=9 train smooth_l1 <loss>=(0.6359600100600928)
# [01/25/2023 21:58:12 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:58:12 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:58:14 INFO 139680548325184] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.006209644988269154)
# [01/25/2023 21:58:14 INFO 139680548325184] Updating the best model with validation-mAP=0.006209644988269154
# [01/25/2023 21:58:14 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:58:14 INFO 139680548325184] #progress_metric: host=algo-1, completed 12.0 % of epochs
# #metrics {"StartTime": 1674683890.193176, "EndTime": 1674683894.943398, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 11, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:58:17 INFO 139680548325184] #quality_metric: host=algo-1, epoch=12, batch=9 train cross_entropy <loss>=(1.672646771145238)
# [01/25/2023 21:58:17 INFO 139680548325184] #quality_metric: host=algo-1, epoch=12, batch=9 train smooth_l1 <loss>=(0.6282380805405198)
# [01/25/2023 21:58:17 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:58:17 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:58:19 INFO 139680548325184] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.00797511404170628)
# [01/25/2023 21:58:19 INFO 139680548325184] Updating the best model with validation-mAP=0.00797511404170628
# [01/25/2023 21:58:19 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:58:19 INFO 139680548325184] #progress_metric: host=algo-1, completed 13.0 % of epochs
# #metrics {"StartTime": 1674683894.943596, "EndTime": 1674683899.7073884, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 12, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:58:22 INFO 139680548325184] #quality_metric: host=algo-1, epoch=13, batch=10 train cross_entropy <loss>=(1.653102624105184)
# [01/25/2023 21:58:22 INFO 139680548325184] #quality_metric: host=algo-1, epoch=13, batch=10 train smooth_l1 <loss>=(0.6163506769683316)
# [01/25/2023 21:58:22 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:58:22 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:58:24 INFO 139680548325184] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.01277972826838035)
# [01/25/2023 21:58:24 INFO 139680548325184] Updating the best model with validation-mAP=0.01277972826838035
# [01/25/2023 21:58:24 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:58:24 INFO 139680548325184] #progress_metric: host=algo-1, completed 14.0 % of epochs
# #metrics {"StartTime": 1674683899.7075737, "EndTime": 1674683904.9162655, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 13, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 14.0, "count": 1, "min": 14, "max": 14}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:58:27 INFO 139680548325184] #quality_metric: host=algo-1, epoch=14, batch=9 train cross_entropy <loss>=(1.6233577607297998)
# [01/25/2023 21:58:27 INFO 139680548325184] #quality_metric: host=algo-1, epoch=14, batch=9 train smooth_l1 <loss>=(0.6067904659859978)
# [01/25/2023 21:58:27 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:58:27 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:58:29 INFO 139680548325184] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(0.013039152397528597)
# [01/25/2023 21:58:29 INFO 139680548325184] Updating the best model with validation-mAP=0.013039152397528597
# [01/25/2023 21:58:29 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:58:29 INFO 139680548325184] #progress_metric: host=algo-1, completed 15.0 % of epochs
# #metrics {"StartTime": 1674683904.9164786, "EndTime": 1674683909.7320096, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:58:32 INFO 139680548325184] #quality_metric: host=algo-1, epoch=15, batch=9 train cross_entropy <loss>=(1.59488525390625)
# [01/25/2023 21:58:32 INFO 139680548325184] #quality_metric: host=algo-1, epoch=15, batch=9 train smooth_l1 <loss>=(0.6189184877061352)
# [01/25/2023 21:58:32 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:58:32 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:58:34 INFO 139680548325184] #quality_metric: host=algo-1, epoch=15, validation mAP <score>=(0.015028056253438801)
# [01/25/2023 21:58:34 INFO 139680548325184] Updating the best model with validation-mAP=0.015028056253438801
# [01/25/2023 21:58:35 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:58:35 INFO 139680548325184] #progress_metric: host=algo-1, completed 16.0 % of epochs
# #metrics {"StartTime": 1674683909.7322187, "EndTime": 1674683915.5733793, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 15, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:58:38 INFO 139680548325184] #quality_metric: host=algo-1, epoch=16, batch=10 train cross_entropy <loss>=(1.542483640211568)
# [01/25/2023 21:58:38 INFO 139680548325184] #quality_metric: host=algo-1, epoch=16, batch=10 train smooth_l1 <loss>=(0.6017384335627096)
# [01/25/2023 21:58:38 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:58:38 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:58:40 INFO 139680548325184] #quality_metric: host=algo-1, epoch=16, validation mAP <score>=(0.023878435565520422)
# [01/25/2023 21:58:40 INFO 139680548325184] Updating the best model with validation-mAP=0.023878435565520422
# [01/25/2023 21:58:41 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:58:41 INFO 139680548325184] #progress_metric: host=algo-1, completed 17.0 % of epochs
# #metrics {"StartTime": 1674683915.573544, "EndTime": 1674683921.2032375, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 16, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:58:43 INFO 139680548325184] #quality_metric: host=algo-1, epoch=17, batch=9 train cross_entropy <loss>=(1.4923639905774915)
# [01/25/2023 21:58:43 INFO 139680548325184] #quality_metric: host=algo-1, epoch=17, batch=9 train smooth_l1 <loss>=(0.5910455528465477)
# [01/25/2023 21:58:43 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:58:43 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:58:45 INFO 139680548325184] #quality_metric: host=algo-1, epoch=17, validation mAP <score>=(0.02237827902386628)
# [01/25/2023 21:58:45 INFO 139680548325184] #progress_metric: host=algo-1, completed 18.0 % of epochs
# #metrics {"StartTime": 1674683921.2034533, "EndTime": 1674683925.639614, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 17, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 18.0, "count": 1, "min": 18, "max": 18}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:58:48 INFO 139680548325184] #quality_metric: host=algo-1, epoch=18, batch=10 train cross_entropy <loss>=(1.4307605259454073)
# [01/25/2023 21:58:48 INFO 139680548325184] #quality_metric: host=algo-1, epoch=18, batch=10 train smooth_l1 <loss>=(0.5940232632765129)
# [01/25/2023 21:58:48 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:58:48 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:58:50 INFO 139680548325184] #quality_metric: host=algo-1, epoch=18, validation mAP <score>=(0.031186972273775548)
# [01/25/2023 21:58:50 INFO 139680548325184] Updating the best model with validation-mAP=0.031186972273775548
# [01/25/2023 21:58:50 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:58:50 INFO 139680548325184] #progress_metric: host=algo-1, completed 19.0 % of epochs
# #metrics {"StartTime": 1674683925.6398373, "EndTime": 1674683930.7804182, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 18, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:58:53 INFO 139680548325184] #quality_metric: host=algo-1, epoch=19, batch=9 train cross_entropy <loss>=(1.3937149276048806)
# [01/25/2023 21:58:53 INFO 139680548325184] #quality_metric: host=algo-1, epoch=19, batch=9 train smooth_l1 <loss>=(0.630278004487514)
# [01/25/2023 21:58:53 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:58:53 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:58:55 INFO 139680548325184] #quality_metric: host=algo-1, epoch=19, validation mAP <score>=(0.038814874772975)
# [01/25/2023 21:58:55 INFO 139680548325184] Updating the best model with validation-mAP=0.038814874772975
# [01/25/2023 21:58:55 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:58:55 INFO 139680548325184] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1674683930.7806315, "EndTime": 1674683935.6831162, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 19, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 20.0, "count": 1, "min": 20, "max": 20}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:58:58 INFO 139680548325184] #quality_metric: host=algo-1, epoch=20, batch=9 train cross_entropy <loss>=(1.3492661271910302)
# [01/25/2023 21:58:58 INFO 139680548325184] #quality_metric: host=algo-1, epoch=20, batch=9 train smooth_l1 <loss>=(0.6214223760518671)
# [01/25/2023 21:58:58 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:58:58 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:59:00 INFO 139680548325184] #quality_metric: host=algo-1, epoch=20, validation mAP <score>=(0.05590879193109137)
# [01/25/2023 21:59:00 INFO 139680548325184] Updating the best model with validation-mAP=0.05590879193109137
# [01/25/2023 21:59:00 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:59:00 INFO 139680548325184] #progress_metric: host=algo-1, completed 21.0 % of epochs
# #metrics {"StartTime": 1674683935.6833098, "EndTime": 1674683940.7859685, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 20, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 21.0, "count": 1, "min": 21, "max": 21}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:59:03 INFO 139680548325184] #quality_metric: host=algo-1, epoch=21, batch=10 train cross_entropy <loss>=(1.3126215916342716)
# [01/25/2023 21:59:03 INFO 139680548325184] #quality_metric: host=algo-1, epoch=21, batch=10 train smooth_l1 <loss>=(0.5748916169391175)
# [01/25/2023 21:59:03 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:59:03 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:59:05 INFO 139680548325184] #quality_metric: host=algo-1, epoch=21, validation mAP <score>=(0.050108317840049564)
# [01/25/2023 21:59:05 INFO 139680548325184] #progress_metric: host=algo-1, completed 22.0 % of epochs
# #metrics {"StartTime": 1674683940.786179, "EndTime": 1674683945.576397, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 21, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 22.0, "count": 1, "min": 22, "max": 22}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:59:08 INFO 139680548325184] #quality_metric: host=algo-1, epoch=22, batch=9 train cross_entropy <loss>=(1.2491616989104666)
# [01/25/2023 21:59:08 INFO 139680548325184] #quality_metric: host=algo-1, epoch=22, batch=9 train smooth_l1 <loss>=(0.5943007809081534)
# [01/25/2023 21:59:08 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:59:08 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:59:09 INFO 139680548325184] #quality_metric: host=algo-1, epoch=22, validation mAP <score>=(0.04835988522421718)
# [01/25/2023 21:59:09 INFO 139680548325184] #progress_metric: host=algo-1, completed 23.0 % of epochs
# #metrics {"StartTime": 1674683945.5766418, "EndTime": 1674683949.983472, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 22, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 23.0, "count": 1, "min": 23, "max": 23}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:59:12 INFO 139680548325184] #quality_metric: host=algo-1, epoch=23, batch=9 train cross_entropy <loss>=(1.230727034471229)
# [01/25/2023 21:59:12 INFO 139680548325184] #quality_metric: host=algo-1, epoch=23, batch=9 train smooth_l1 <loss>=(0.5897908220709241)
# [01/25/2023 21:59:12 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:59:12 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:59:14 INFO 139680548325184] #quality_metric: host=algo-1, epoch=23, validation mAP <score>=(0.06669540152341617)
# [01/25/2023 21:59:14 INFO 139680548325184] Updating the best model with validation-mAP=0.06669540152341617
# [01/25/2023 21:59:14 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:59:14 INFO 139680548325184] #progress_metric: host=algo-1, completed 24.0 % of epochs
# #metrics {"StartTime": 1674683949.98369, "EndTime": 1674683954.7892756, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 23, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 24.0, "count": 1, "min": 24, "max": 24}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 21:59:18 INFO 139680548325184] #quality_metric: host=algo-1, epoch=24, batch=10 train cross_entropy <loss>=(1.1752818341595452)
# [01/25/2023 21:59:18 INFO 139680548325184] #quality_metric: host=algo-1, epoch=24, batch=10 train smooth_l1 <loss>=(0.5768447346468242)
# [01/25/2023 21:59:18 INFO 139680548325184] Round of batches complete
# [01/25/2023 21:59:18 INFO 139680548325184] Updated the metrics
# [01/25/2023 21:59:19 INFO 139680548325184] #quality_metric: host=algo-1, epoch=24, validation mAP <score>=(0.0884900029797974)
# [01/25/2023 21:59:19 INFO 139680548325184] Updating the best model with validation-mAP=0.0884900029797974
# [01/25/2023 21:59:20 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 21:59:20 INFO 139680548325184] #progress_metric: host=algo-1, completed 25.0 % of epochs
# ...
# [01/25/2023 22:04:20 INFO 139680548325184] Updated the metrics
# [01/25/2023 22:04:21 INFO 139680548325184] #quality_metric: host=algo-1, epoch=89, validation mAP <score>=(0.17864374090978785)
# [01/25/2023 22:04:21 INFO 139680548325184] #progress_metric: host=algo-1, completed 90.0 % of epochs
# #metrics {"StartTime": 1674684257.3374302, "EndTime": 1674684261.7628887, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 89, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 90.0, "count": 1, "min": 90, "max": 90}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 22:04:24 INFO 139680548325184] #quality_metric: host=algo-1, epoch=90, batch=10 train cross_entropy <loss>=(0.9480803037753924)
# [01/25/2023 22:04:24 INFO 139680548325184] #quality_metric: host=algo-1, epoch=90, batch=10 train smooth_l1 <loss>=(0.5201038530862343)
# [01/25/2023 22:04:24 INFO 139680548325184] Round of batches complete
# [01/25/2023 22:04:24 INFO 139680548325184] Updated the metrics
# [01/25/2023 22:04:26 INFO 139680548325184] #quality_metric: host=algo-1, epoch=90, validation mAP <score>=(0.16608912913014415)
# [01/25/2023 22:04:26 INFO 139680548325184] #progress_metric: host=algo-1, completed 91.0 % of epochs
# #metrics {"StartTime": 1674684261.763121, "EndTime": 1674684266.3720741, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 90, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 91.0, "count": 1, "min": 91, "max": 91}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 22:04:29 INFO 139680548325184] #quality_metric: host=algo-1, epoch=91, batch=9 train cross_entropy <loss>=(0.9570945641723895)
# [01/25/2023 22:04:29 INFO 139680548325184] #quality_metric: host=algo-1, epoch=91, batch=9 train smooth_l1 <loss>=(0.5210922657805286)
# [01/25/2023 22:04:29 INFO 139680548325184] Round of batches complete
# [01/25/2023 22:04:29 INFO 139680548325184] Updated the metrics
# [01/25/2023 22:04:30 INFO 139680548325184] #quality_metric: host=algo-1, epoch=91, validation mAP <score>=(0.153182984097279)
# [01/25/2023 22:04:30 INFO 139680548325184] #progress_metric: host=algo-1, completed 92.0 % of epochs
# #metrics {"StartTime": 1674684266.3723116, "EndTime": 1674684270.7267416, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 91, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 92.0, "count": 1, "min": 92, "max": 92}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 22:04:33 INFO 139680548325184] #quality_metric: host=algo-1, epoch=92, batch=9 train cross_entropy <loss>=(0.959672702088648)
# [01/25/2023 22:04:33 INFO 139680548325184] #quality_metric: host=algo-1, epoch=92, batch=9 train smooth_l1 <loss>=(0.5287038842026068)
# [01/25/2023 22:04:33 INFO 139680548325184] Round of batches complete
# [01/25/2023 22:04:33 INFO 139680548325184] Updated the metrics
# [01/25/2023 22:04:35 INFO 139680548325184] #quality_metric: host=algo-1, epoch=92, validation mAP <score>=(0.15251783658555085)
# [01/25/2023 22:04:35 INFO 139680548325184] #progress_metric: host=algo-1, completed 93.0 % of epochs
# #metrics {"StartTime": 1674684270.7269697, "EndTime": 1674684275.123844, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 92, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 93.0, "count": 1, "min": 93, "max": 93}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 22:04:38 INFO 139680548325184] #quality_metric: host=algo-1, epoch=93, batch=10 train cross_entropy <loss>=(0.970306265194603)
# [01/25/2023 22:04:38 INFO 139680548325184] #quality_metric: host=algo-1, epoch=93, batch=10 train smooth_l1 <loss>=(0.5336117972379433)
# [01/25/2023 22:04:38 INFO 139680548325184] Round of batches complete
# [01/25/2023 22:04:38 INFO 139680548325184] Updated the metrics
# [01/25/2023 22:04:39 INFO 139680548325184] #quality_metric: host=algo-1, epoch=93, validation mAP <score>=(0.17225448882828243)
# [01/25/2023 22:04:39 INFO 139680548325184] #progress_metric: host=algo-1, completed 94.0 % of epochs
# #metrics {"StartTime": 1674684275.1240606, "EndTime": 1674684279.7926426, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 93, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 94.0, "count": 1, "min": 94, "max": 94}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 22:04:42 INFO 139680548325184] #quality_metric: host=algo-1, epoch=94, batch=9 train cross_entropy <loss>=(0.9531880062764176)
# [01/25/2023 22:04:42 INFO 139680548325184] #quality_metric: host=algo-1, epoch=94, batch=9 train smooth_l1 <loss>=(0.5137174967695273)
# [01/25/2023 22:04:42 INFO 139680548325184] Round of batches complete
# [01/25/2023 22:04:42 INFO 139680548325184] Updated the metrics
# [01/25/2023 22:04:44 INFO 139680548325184] #quality_metric: host=algo-1, epoch=94, validation mAP <score>=(0.16850056747865694)
# [01/25/2023 22:04:44 INFO 139680548325184] #progress_metric: host=algo-1, completed 95.0 % of epochs
# #metrics {"StartTime": 1674684279.792884, "EndTime": 1674684284.1057062, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 94, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 95.0, "count": 1, "min": 95, "max": 95}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 22:04:46 INFO 139680548325184] #quality_metric: host=algo-1, epoch=95, batch=9 train cross_entropy <loss>=(0.9476973708642242)
# [01/25/2023 22:04:46 INFO 139680548325184] #quality_metric: host=algo-1, epoch=95, batch=9 train smooth_l1 <loss>=(0.5352563418162817)
# [01/25/2023 22:04:46 INFO 139680548325184] Round of batches complete
# [01/25/2023 22:04:46 INFO 139680548325184] Updated the metrics
# [01/25/2023 22:04:48 INFO 139680548325184] #quality_metric: host=algo-1, epoch=95, validation mAP <score>=(0.15907742996349217)
# [01/25/2023 22:04:48 INFO 139680548325184] #progress_metric: host=algo-1, completed 96.0 % of epochs
# #metrics {"StartTime": 1674684284.1059513, "EndTime": 1674684288.7608182, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 95, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 96.0, "count": 1, "min": 96, "max": 96}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 22:04:52 INFO 139680548325184] #quality_metric: host=algo-1, epoch=96, batch=10 train cross_entropy <loss>=(0.9663563522000939)
# [01/25/2023 22:04:52 INFO 139680548325184] #quality_metric: host=algo-1, epoch=96, batch=10 train smooth_l1 <loss>=(0.5533772912098561)
# [01/25/2023 22:04:52 INFO 139680548325184] Round of batches complete
# [01/25/2023 22:04:52 INFO 139680548325184] Updated the metrics
# [01/25/2023 22:04:53 INFO 139680548325184] #quality_metric: host=algo-1, epoch=96, validation mAP <score>=(0.16485164376111178)
# [01/25/2023 22:04:53 INFO 139680548325184] #progress_metric: host=algo-1, completed 97.0 % of epochs
# #metrics {"StartTime": 1674684288.7610996, "EndTime": 1674684293.7774606, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 96, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 97.0, "count": 1, "min": 97, "max": 97}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 22:04:56 INFO 139680548325184] #quality_metric: host=algo-1, epoch=97, batch=9 train cross_entropy <loss>=(0.9476650539808292)
# [01/25/2023 22:04:56 INFO 139680548325184] #quality_metric: host=algo-1, epoch=97, batch=9 train smooth_l1 <loss>=(0.547937625320156)
# [01/25/2023 22:04:56 INFO 139680548325184] Round of batches complete
# [01/25/2023 22:04:56 INFO 139680548325184] Updated the metrics
# [01/25/2023 22:04:58 INFO 139680548325184] #quality_metric: host=algo-1, epoch=97, validation mAP <score>=(0.13096132845882477)
# [01/25/2023 22:04:58 INFO 139680548325184] #progress_metric: host=algo-1, completed 98.0 % of epochs
# #metrics {"StartTime": 1674684293.7776914, "EndTime": 1674684298.138955, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 97, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 98.0, "count": 1, "min": 98, "max": 98}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 22:05:01 INFO 139680548325184] #quality_metric: host=algo-1, epoch=98, batch=10 train cross_entropy <loss>=(0.9453086637101084)
# [01/25/2023 22:05:01 INFO 139680548325184] #quality_metric: host=algo-1, epoch=98, batch=10 train smooth_l1 <loss>=(0.5211560879113539)
# [01/25/2023 22:05:01 INFO 139680548325184] Round of batches complete
# [01/25/2023 22:05:01 INFO 139680548325184] Updated the metrics
# [01/25/2023 22:05:02 INFO 139680548325184] #quality_metric: host=algo-1, epoch=98, validation mAP <score>=(0.16852128178752615)
# [01/25/2023 22:05:02 INFO 139680548325184] #progress_metric: host=algo-1, completed 99.0 % of epochs
# #metrics {"StartTime": 1674684298.139232, "EndTime": 1674684302.7895799, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 98, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 99.0, "count": 1, "min": 99, "max": 99}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 22:05:05 INFO 139680548325184] #quality_metric: host=algo-1, epoch=99, batch=9 train cross_entropy <loss>=(0.9633892124897308)
# [01/25/2023 22:05:05 INFO 139680548325184] #quality_metric: host=algo-1, epoch=99, batch=9 train smooth_l1 <loss>=(0.5317466936410378)
# [01/25/2023 22:05:05 INFO 139680548325184] Round of batches complete
# [01/25/2023 22:05:05 INFO 139680548325184] Updated the metrics
# [01/25/2023 22:05:07 INFO 139680548325184] #quality_metric: host=algo-1, epoch=99, validation mAP <score>=(0.16211697959218158)
# [01/25/2023 22:05:07 INFO 139680548325184] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1674684302.7898152, "EndTime": 1674684307.222102, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 99, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [01/25/2023 22:05:07 WARNING 139680548325184] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/25/2023 22:05:07 INFO 139680548325184] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/25/2023 22:05:07 INFO 139680548325184] Test data is not provided.
# #metrics {"StartTime": 1674683823.9896593, "EndTime": 1674684307.957958, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "setuptime": {"sum": 6.772756576538086, "count": 1, "min": 6.772756576538086, "max": 6.772756576538086}, "totaltime": {"sum": 484078.2256126404, "count": 1, "min": 484078.2256126404, "max": 484078.2256126404}}}
#
# 2023-01-25 22:05:11 Uploading - Uploading generated training model
# 2023-01-25 22:05:37 Completed - Training job completed
# Training seconds: 715
# Billable seconds: 715
# CPU times: user 1.66 s, sys: 78 ms, total: 1.74 s
# Wall time: 13min 57s

# %% [markdown]
# ## Plot mAP vs epochs

# %%
import boto3
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %matplotlib inline

client = boto3.client("logs")
BASE_LOG_NAME = "/aws/sagemaker/TrainingJobs"


def plot_object_detection_log(model, title):
    logs = client.describe_log_streams(
        logGroupName=BASE_LOG_NAME, logStreamNamePrefix=model._current_job_name
    )
    cw_log = client.get_log_events(
        logGroupName=BASE_LOG_NAME, logStreamName=logs["logStreams"][0]["logStreamName"]
    )

    mAP_accs = []
    for e in cw_log["events"]:
        msg = e["message"]
        if "validation mAP <score>=" in msg:
            num_start = msg.find("(")
            num_end = msg.find(")")
            mAP = msg[num_start + 1 : num_end]
            mAP_accs.append(float(mAP))

    print(title)
    print("Maximum mAP: %f " % max(mAP_accs))

    fig, ax = plt.subplots()
    plt.xlabel("Epochs")
    plt.ylabel("Mean Avg Precision (mAP)")
    (val_plot,) = ax.plot(range(len(mAP_accs)), mAP_accs, label="mAP")
    plt.legend(handles=[val_plot])
    ax.yaxis.set_ticks(np.arange(0.0, 1.05, 0.1))
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter("%0.2f"))
    plt.show()

# %%
plot_object_detection_log(od_model, "mAP tracking for job: " + od_model._current_job_name)
# Out:
# mAP tracking for job: object-detection-2023-01-25-21-52-12-125
# Maximum mAP: 0.184443
